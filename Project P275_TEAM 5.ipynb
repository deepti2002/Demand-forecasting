# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # EDA

# %% [markdown]
# ##### In EDA, you perform various data manipulation, visualization, and summary techniques to understand the data's structure and distribution better. This helps you make informed decisions about data preprocessing, feature engineering, and model selection during the data analysis process.

# %% [markdown]
# # Loading and Exploring the data"

# %%
#Load and Explore the Data:
#Load the "train.csv" data into a DataFrame using your preferred programming language (e.g., Python with pandas).
#Check the first few rows of the DataFrame to get an initial view of the data.
#Check the data types of each column and identify any missing values.

# %%
#Load the Data
data = pd.read_csv("/Users/deeptilalwani/Documents/Data Science/PROJECT 1/train.csv")

# %%
data
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3000883  3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# ...

# %%
data.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
data.describe()
# Out:
#                  id     store_nbr         sales   onpromotion
# count  3.000888e+06  3.000888e+06  3.000888e+06  3.000888e+06
# mean   1.500444e+06  2.750000e+01  3.577757e+02  2.602770e+00
# std    8.662819e+05  1.558579e+01  1.101998e+03  1.221888e+01
# min    0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    7.502218e+05  1.400000e+01  0.000000e+00  0.000000e+00
# 50%    1.500444e+06  2.750000e+01  1.100000e+01  0.000000e+00
# 75%    2.250665e+06  4.100000e+01  1.958473e+02  0.000000e+00
# max    3.000887e+06  5.400000e+01  1.247170e+05  7.410000e+02

# %%
data.info
# Out:
# <bound method DataFrame.info of               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3000883  3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887  2017-08-15          9                     SEAFOOD    16.000
#
# ...

# %%
# Check data types of each column
data_types = data.dtypes
print("Data Types:")
print(data_types)
# Out:
# Data Types:
# id               int64
# date            object
# store_nbr        int64
# family          object
# sales          float64
# onpromotion      int64
# dtype: object

# %%
# Check for missing values in each column
missing_values = data.isnull().sum()
print("\nMissing Values:")
print(missing_values)
# Out:
# Missing Values:
# id             0
# date           0
# store_nbr      0
# family         0
# sales          0
# onpromotion    0
# dtype: int64

# %% [markdown]
# ##### Since there are no missing values, there is no need to perform imputation or removal of missing data in this specific dataset.

# %% [markdown]
# # Data Summary:
# ##### Generate summary statistics of the numerical columns, such as mean, median, min, max, and standard deviation. This will provide an overview of the data distribution.

# %%
# Generate summary statistics of numerical columns
summary_stats = data.describe()
print(summary_stats)
# Out:
#                  id     store_nbr         sales   onpromotion
# count  3.000888e+06  3.000888e+06  3.000888e+06  3.000888e+06
# mean   1.500444e+06  2.750000e+01  3.577757e+02  2.602770e+00
# std    8.662819e+05  1.558579e+01  1.101998e+03  1.221888e+01
# min    0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    7.502218e+05  1.400000e+01  0.000000e+00  0.000000e+00
# 50%    1.500444e+06  2.750000e+01  1.100000e+01  0.000000e+00
# 75%    2.250665e+06  4.100000e+01  1.958473e+02  0.000000e+00
# max    3.000887e+06  5.400000e+01  1.247170e+05  7.410000e+02

# %% [markdown]
# ### INSIGHTS:
# #### id:
# ##### The minimum id is 0, and the maximum id is 3,000,887, indicating that there are 3,000,888 data points.
# ##### The mean id is approximately 1,500,444, which suggests that the data might be evenly distributed.
# ##### The standard deviation of id is approximately 866,281, indicating some variability in the data.
#
# #### store_nbr:
# ##### The minimum store_nbr is 1, and the maximum store_nbr is 54.
# ##### The mean store_nbr is 27.5, which indicates that there are 54 stores in total.
# ##### The standard deviation of store_nbr is approximately 15.6, suggesting that the stores might not be evenly distributed.
#
# #### sales:
# ##### The minimum sales value is 0, indicating that there are instances of zero sales.
# ##### The maximum sales value is 124,717, indicating that there are stores with very high sales.
# ##### The mean sales value is approximately 357.8, suggesting an overall moderate level of sales.
# ##### The standard deviation of sales is approximately 1,102, indicating significant variability in sales across different stores or time periods.
#
# #### onpromotion:
# ##### The minimum onpromotion value is 0, indicating that there are instances where products are not on promotion.
# ##### The maximum onpromotion value is 741, indicating a wide range of promotion occurrences.
# ##### The mean onpromotion value is approximately 2.6, suggesting an average promotion frequency.
# ##### The standard deviation of onpromotion is approximately 12.2, indicating significant variability in promotion occurrences.

# %% [markdown]
# ##### These extracted features can be useful for time-based analysis and visualization.

# %% [markdown]
# # Data Visualization :

# %%
data
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3000883  3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# ...

# %%
# Find the earliest and latest dates
earliest_date = data['date'].min()
latest_date = data['date'].max()

print("Earliest Date:", earliest_date)
print("Latest Date:", latest_date)
# Out:
# Earliest Date: 2013-01-01
# Latest Date: 2017-08-15

# %%
# Plot "onpromotion" against time
plt.figure(figsize=(12, 6))
plt.plot(data['date'], data['onpromotion'])
plt.xlabel('Date')
plt.ylabel('On Promotion')
plt.title('On Promotion over Time')
plt.grid(True)
plt.show()

# %%
# Convert the "date" column to datetime format
data['date'] = pd.to_datetime(data['date'])

# %%
data
# Out:
#               id       date  store_nbr                      family     sales  \
# 0              0 2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1 2013-01-01          1                   BABY CARE     0.000
# 2              2 2013-01-01          1                      BEAUTY     0.000
# 3              3 2013-01-01          1                   BEVERAGES     0.000
# 4              4 2013-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 3000883  3000883 2017-08-15          9                     POULTRY   438.133
# 3000884  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885 2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# 0                  0
# ...

# %%
# Filter data for non-zero sales
non_zero_sales_data = data[data['sales'] > 0]
non_zero_sales_data
# Out:
#               id       date  store_nbr                      family     sales  \
# 563          563 2013-01-01         25                      BEAUTY     2.000
# 564          564 2013-01-01         25                   BEVERAGES   810.000
# 566          566 2013-01-01         25                BREAD/BAKERY   180.589
# 568          568 2013-01-01         25                    CLEANING   186.000
# 569          569 2013-01-01         25                       DAIRY   143.000
# ...          ...        ...        ...                         ...       ...
# 3000883  3000883 2017-08-15          9                     POULTRY   438.133
# 3000884  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885 2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# 563                0
# ...

# %%
# Bar Plot: Plot the total sales for each family
family_sales = data.groupby('family')['sales'].sum().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
family_sales.plot(kind='bar')
plt.xlabel('Family')
plt.ylabel('Total Sales')
plt.title('Total Sales by Family')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Box Plot: Visualize the distribution of sales for each family
plt.figure(figsize=(10, 6))
data.boxplot(column='sales', by='family', vert=False)
plt.xlabel('Sales')
plt.ylabel('Family')
plt.title('Distribution of Sales by Family')
plt.tight_layout()
plt.show()

# %%
# Scatter Plot: Explore the relationship between sales and onpromotion
plt.figure(figsize=(10, 6))
plt.scatter(data['onpromotion'], data['sales'], alpha=0.5)
plt.xlabel('On Promotion')
plt.ylabel('Sales')
plt.title('Scatter Plot of Sales vs. On Promotion')
plt.xticks([0, 1])
plt.tight_layout()
plt.show()

# %% [markdown]
# # Check for Stationarity:

# %% [markdown]
# ##  Plot the Time Series Data:

# %%
data.set_index('date', inplace=True)

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['sales'], label='Sales', linestyle='-', marker='o', color='b')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Time Series Line Plot of Sales')
plt.legend()
plt.grid(True) 
plt.show()

# %% [markdown]
# ## Use the Augmented Dickey-Fuller (ADF) Test:

# %%
#The ADF test is a statistical test used to determine whether a time series is stationary or not.

# %%
from statsmodels.tsa.stattools import adfuller

# result = adfuller(data['sales'])

# print('ADF Statistic:', result[0])
# print('p-value:', result[1])
# print('Critical Values:', result[4])

# %% [markdown]
# ##### As we have a large dataset, Using a sample or aggregating the data can be helpful to speed up the ADF test

# %% [markdown]
# ### Aggregating the Data:
# ###### Aggregating involves summarizing the data over larger time intervals. For example, if data is recorded on a daily basis, we can aggregate it to weekly or monthly intervals. This reduces the number of data points while retaining the overall trends and patterns.

# %%
data
# Out:
#                  id  store_nbr                      family     sales  \
# date
# 2013-01-01        0          1                  AUTOMOTIVE     0.000
# 2013-01-01        1          1                   BABY CARE     0.000
# 2013-01-01        2          1                      BEAUTY     0.000
# 2013-01-01        3          1                   BEVERAGES     0.000
# 2013-01-01        4          1                       BOOKS     0.000
# ...             ...        ...                         ...       ...
# 2017-08-15  3000883          9                     POULTRY   438.133
# 2017-08-15  3000884          9              PREPARED FOODS   154.553
# 2017-08-15  3000885          9                     PRODUCE  2419.729
# 2017-08-15  3000886          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 2017-08-15  3000887          9                     SEAFOOD    16.000
#
#             onpromotion
# date
# 2013-01-01            0
# 2013-01-01            0
# 2013-01-01            0
# ...

# %%
aggregated_data = data.resample('W-Mon').sum()  # Aggregating to weekly intervals

result = adfuller(aggregated_data['sales'].dropna())

print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:', result[4])
# Out:
# ADF Statistic: -2.004078899958857
# p-value: 0.2847875125403818
# Critical Values: {'1%': -3.458854867412691, '5%': -2.8740800599399323, '10%': -2.573453223097503}
# /var/folders/c1/y9rtpw857h729s9ssm0kwlmw0000gn/T/ipykernel_4772/2581307827.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   aggregated_data = data.resample('W-Mon').sum()  # Aggregating to weekly intervals

# %% [markdown]
# ###### Based on the ADF test results, the p-value (0.2847875125403818) is greater than the significance levels of 1%, 5%, and 10%. This indicates that you fail to reject the null hypothesis. The null hypothesis in the ADF test is that the data contains a unit root (it is non-stationary). The higher p-value suggests that the data might indeed be non-stationary.

# %% [markdown]
# # Make Data Stationary:

# %% [markdown]
# ## Differencing:

# %%
# Assuming your time series data is in a DataFrame called 'data'
aggregated_data['diff_sales'] = aggregated_data['sales'] - aggregated_data['sales'].shift(1)
aggregated_data['diff_sales'].dropna(inplace=True)

# %%
# Assuming your differenced, aggregated data is in a DataFrame called 'aggregated_data'
result_diff_aggregated = adfuller(aggregated_data['diff_sales'].dropna())

print('ADF Statistic:', result_diff_aggregated[0])
print('p-value:', result_diff_aggregated[1])
print('Critical Values:', result_diff_aggregated[4])
# Out:
# ADF Statistic: -4.2722310501188945
# p-value: 0.000496054070068327
# Critical Values: {'1%': -3.4589796764641, '5%': -2.8741347158661448, '10%': -2.573482381701992}

# %% [markdown]
# ##### Based on the ADF test results, the p-value ( 0.000496054070068327) is below the significance levels of 1%, 5%, and 10%. This suggests that you can reject the null hypothesis, indicating that the differenced, aggregated data is stationary.

# %% [markdown]
# ## But,this doesn't automatically imply that the entire original dataset is also stationary.
# ## it's important to consider the characteristics of the original data before making a final decision.
#
# ## We check with :
# ## Rolling Statistics:
# #### Calculate rolling statistics (e.g., rolling mean and rolling standard deviation) and plot them against the original data. If these statistics remain relatively constant over time, it suggests stationarity.

# %%
# Assuming your time series data is in a DataFrame called 'data'
window = 30  # Choose the size of the rolling window

# Calculate rolling mean and rolling std
data['rolling_mean'] = data['sales'].rolling(window=window).mean()
data['rolling_std'] = data['sales'].rolling(window=window).std()

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['sales'], label='Original Data')
plt.plot(data.index, data['rolling_mean'], label=f'Rolling Mean (Window {window})', color='red')
plt.plot(data.index, data['rolling_std'], label=f'Rolling Std (Window {window})', color='green')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Original Data and Rolling Statistics')
plt.legend()
plt.show()

# %%
# Calculate rolling mean and rolling std for the original data
window = 30  # Choose the size of the rolling window
data['rolling_mean_original'] = data['sales'].rolling(window=window).mean()
data['rolling_std_original'] = data['sales'].rolling(window=window).std()

# Calculate the range of deviations in rolling mean and rolling std for the original data
rolling_mean_deviation_range_original = data['rolling_mean_original'].max() - data['rolling_mean_original'].min()
rolling_std_deviation_range_original = data['rolling_std_original'].max() - data['rolling_std_original'].min()
original_data_range = data['sales'].max() - data['sales'].min()

# Compare the magnitudes to the range of the original data
print(f"Rolling Mean Deviation Range (Original Data): {rolling_mean_deviation_range_original}")
print(f"Rolling Std Deviation Range (Original Data): {rolling_std_deviation_range_original}")
print(f"Original Data Range: {original_data_range}")

# Compare the magnitudes to assess the impact of deviations
if rolling_mean_deviation_range_original < original_data_range and rolling_std_deviation_range_original < original_data_range:
    print("Deviations for the original data are relatively small compared to the data range.")
else:
    print("Deviations for the original data might be significant compared to the data range.")
# Out:
# Rolling Mean Deviation Range (Original Data): 4547.914233333333
# Rolling Std Deviation Range (Original Data): 22729.520908585087
# Original Data Range: 124717.0
# Deviations for the original data are relatively small compared to the data range.

# %% [markdown]
# #### If the rolling mean and rolling standard deviation remain relatively constant or show minimal variation as they move through time, it's an indication that the data might be stationary. But, we are observing significant fluctuations, it suggests non-stationarity.

# %% [markdown]
# ### To make a non-stationary time series data stationary, using Differencing

# %%
# Assuming your time series data is in a DataFrame called 'data'
data['diff_sales'] = data['sales'] - data['sales'].shift(1)
data['diff_sales'].dropna(inplace=True)

# %%
# Calculate rolling mean and rolling standard deviation
window_size = 7  # You can adjust the window size as needed
rolling_mean = data['diff_sales'].rolling(window=window_size).mean()
rolling_std = data['diff_sales'].rolling(window=window_size).std()

# Plot the differenced data, rolling mean, and rolling standard deviation
plt.figure(figsize=(12, 6))
plt.plot(data.index,data['diff_sales'], label='Differenced Sales', color='b')
plt.plot(data.index, rolling_mean, label='Rolling Mean', color='r')
plt.plot(data.index, rolling_std, label='Rolling Std Dev', color='g')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Differenced Data and Rolling Statistics')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate the range of deviations in rolling mean and rolling std
mean_deviation_range = rolling_mean.max() - rolling_mean.min()
std_deviation_range = rolling_std.max() - rolling_std.min()

# Calculate the range of your original data
original_data_range = data['diff_sales'].max() - data['diff_sales'].min()

# Compare the magnitude of deviations to the range of the original data
print("Range of Deviations in Rolling Mean:", mean_deviation_range)
print("Range of Deviations in Rolling Std:", std_deviation_range)
print("Range of Original Data:", original_data_range)
# Out:
# Range of Deviations in Rolling Mean: 35519.28571428571
# Range of Deviations in Rolling Std: 71963.2867297807
# Range of Original Data: 249280.0

# %% [markdown]
# #### The calculations indicate that the deviations in the rolling mean and rolling standard deviation are relatively small compared to the range of our original data. This suggests that the achieved stationarity through the first differencing process is likely sufficient for our modeling and forecasting efforts.

# %%
# Resample the data on a weekly basis, taking the mean value for each week
weekly_data = data['diff_sales'].resample('W').mean().dropna()

# %%
# Perform the ADF test on the weekly data
result = adfuller(weekly_data)

# Extract and print test results
adf_statistic = result[0]
p_value = result[1]

print(f'ADF Statistic: {adf_statistic}')
print(f'p-value: {p_value}')

if p_value <= 0.05:
   print('Reject the null hypothesis. Weekly sampled data is stationary.')
else:
   print('Fail to reject the null hypothesis. Weekly sampled data is non-stationary.')
# Out:
# ADF Statistic: -11.13202685213335
# p-value: 3.2641411695045257e-20
# Reject the null hypothesis. Weekly sampled data is stationary.

# %% [markdown]
# ##### The goal of achieving stationarity is to make the data's statistical properties relatively stable over time, which helps in building accurate time series models.

# %% [markdown]
# # Seasonality and Trends:

# %% [markdown]
# ####  decomposing the time series data to identify trends, seasonality, and residual patterns, and then calculate and visualize the seasonal components.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# #### we have aggregated the data at weekly intervals, we might suspect weekly seasonality.
# #### so we take seasonal period to 7 days.

# %%
# Assuming annual seasonality (52 weeks)
seasonal_period = 52

# %%
result = decomposition = seasonal_decompose(aggregated_data['sales'], model='additive', period=seasonal_period)

# %%
# Plot the decomposed components
plt.figure(figsize=(10, 8))

plt.subplot(4, 1, 1)
plt.plot(aggregated_data.index, aggregated_data['sales'], label='Original')
plt.legend()
plt.ylabel('Original')

plt.subplot(4, 1, 2)
plt.plot(aggregated_data.index, result.trend, label='Trend', color='orange')
plt.legend()
plt.ylabel('Trend')

plt.subplot(4, 1, 3)
plt.plot(aggregated_data.index, result.seasonal, label='Seasonal', color='green')
plt.legend()
plt.ylabel('Seasonal')

plt.subplot(4, 1, 4)
plt.plot(aggregated_data.index, result.resid, label='Residual', color='red')
plt.legend()
plt.ylabel('Residual')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### we can see a seasonality ,we see a repetitive pattern in the seasonality plot, it indicates the presence of a seasonal component in the data.
# ### observation of a clear annual seasonality pattern in the plot confirms that the assumption of a yearly seasonal period

# %% [markdown]
# #### We can see the increasing trend from the dataset.

# %% [markdown]
# ##### The trend component represents the long-term movement or overall direction of the data, without the short-term fluctuations.
#
# ##### The residual component, also known as the remainder or error component, represents the variability in the data that remains after removing the trend and seasonal effects. It includes the random noise or irregular fluctuations that couldn't be explained by the trend and seasonality.

# %% [markdown]
# # Correlation Analysis

# %%
correlation_matrix = data.corr()

# Extract the correlation of 'sales' with other variables
sales_correlations = correlation_matrix['sales']

# Display the correlations sorted in descending order
sorted_correlations = sales_correlations.sort_values(ascending=False)

# Print the correlation values
print(sorted_correlations)
# Out:
# /var/folders/c1/y9rtpw857h729s9ssm0kwlmw0000gn/T/ipykernel_4772/4021419269.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()
# sales                    1.000000
# diff_sales               0.715601
# onpromotion              0.427923
# rolling_mean             0.267954
# rolling_mean_original    0.267954
# rolling_std              0.256031
# rolling_std_original     0.256031
# id                       0.085784
# store_nbr                0.041196
# Name: sales, dtype: float64

# %%
# Create a heatmap
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Positive correlations:
# #### "rolling_mean_diff" and "diff_sales" have the highest positive correlations with "sales," with correlation coefficients of approximately 0.72 and 0.71, as one variable increases,other one increases as well.
# ### :these variables may be important predictors of sales.
# #### "rolling_mean_seasonal_diff" and "seasonal_diff_sales" also have positive correlations with "sales," but they are slightly weaker, with coefficients around 0.55 and 0.48
# #### "onpromotion" has a moderate positive correlation with "sales"(0.44),
# ### suggesting that promotions are associated with higher sales.
# #### "rolling_mean," "rolling_mean_original," "rolling_std," and "rolling_std_original" have positive correlations with "sales," but they are relatively weaker, with coefficients around 0.24 and 0.23.
# #### rolling_std_diff" and "rolling_std_seasonal_diff" have the weakest positive correlations with "sales," (0.17 and 0.16)
#
# #### The variables "id" and "store_nbr" have very weak positive correlations with "sales," with coefficients around 0.09 and 0.02, respectively. These correlations are close to zero, indicating little to no linear relationship.

# %% [markdown]
# # Promotion Analysis:

# %% [markdown]
# #### comparing sales when promotions are active (onpromotion = 1) versus when they are not (onpromotion = 0).

# %%
# FILTERING THE DATA

# Create two dataframes: one for sales during promotions and one for sales without promotions
sales_with_promotion = data[data['onpromotion'] == 1]
sales_without_promotion = data[data['onpromotion'] == 0]

# %%
# Plot sales vs. active and inactive promotion using a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=['With Promotion', 'Without Promotion'], y=[sales_with_promotion['sales'].mean(),sales_without_promotion['sales'].mean()])
plt.title('Sales vs. Active and Inactive Promotion')
plt.ylabel('Average Sales')
plt.show()

# %% [markdown]
# #### there are more instances of higher sales during active promotions compared to inactive promotions.

# %%
# Create box plots
plt.boxplot([sales_with_promotion['sales'], sales_without_promotion['sales']], labels=['Active', 'Inactive'])  # Specify ['sales'] here
plt.xlabel('Promotion Status')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ##### The box for "Active Promotions" is higher, indicating a higher median sales value during active promotions.
# ##### The whiskers in the "Active Promotions" box plot extend to higher sales values, suggesting a wider range of sales during active promotions.
# ##### There are some potential outliers in both "Active" and "Inactive" promotions, indicating unusually high sales in a few instances.

# %% [markdown]
# # Store vs Family
# #### To know: average sales, highest-selling products

# %%
# Sort the data by 'store_nbr' and 'sales' in descending order
sorted_data = data.sort_values(by=['store_nbr', 'sales'], ascending=[True, False])

# Group the sorted data by 'store_nbr'
store_group = sorted_data.groupby('store_nbr')

# %%
# Get the first (highest-selling) family for each store
highest_selling_family = store_group['family'].first()

# %%
# Create a DataFrame to store the results
store_insights = pd.DataFrame({
    'Store Number': highest_selling_family.index,
    'Highest Selling Family': highest_selling_family.values
})

# Display the insights
print(store_insights)
# Out:
#     Store Number Highest Selling Family
# 0              1              GROCERY I
# 1              2              GROCERY I
# 2              3              GROCERY I
# 3              4              GROCERY I
# 4              5           FROZEN FOODS
# 5              6              GROCERY I
# 6              7              GROCERY I
# 7              8              BEVERAGES
# 8              9              GROCERY I
# 9             10               CLEANING
# 10            11              GROCERY I
# 11            12                  MEATS
# 12            13              GROCERY I
# 13            14              GROCERY I
# 14            15              GROCERY I
# 15            16               CLEANING
# 16            17              GROCERY I
# 17            18              BEVERAGES
# 18            19              GROCERY I
# 19            20              GROCERY I
# 20            21              GROCERY I
# 21            22              GROCERY I
# ...

# %%
#AVERAGE SALES

# Group the data by store and family and calculate the average sales
store_family_group = data.groupby(['store_nbr', 'family'])['sales'].mean().reset_index()

# %%
# Rename the column for clarity
store_family_group = store_family_group.rename(columns={'sales': 'average_sales'})

# Display the resulting DataFrame
print(store_family_group)
# Out:
#       store_nbr                      family  average_sales
# 0             1                  AUTOMOTIVE       3.251188
# 1             1                   BABY CARE       0.000000
# 2             1                      BEAUTY       2.408551
# 3             1                   BEVERAGES    1587.748812
# 4             1                       BOOKS       0.125297
# ...         ...                         ...            ...
# 1777         54                     POULTRY      52.784924
# 1778         54              PREPARED FOODS      61.217340
# 1779         54                     PRODUCE     354.026315
# 1780         54  SCHOOL AND OFFICE SUPPLIES       0.607482
# 1781         54                     SEAFOOD       1.744656
#
# [1782 rows x 3 columns]

# %% [markdown]
# # Outliers and Anomalies

# %%
#VISUAL INSPECTION

# %%
# Scatter plot of sales vs. another numerical variable (e.g., rolling_mean)
plt.figure(figsize=(10, 6))
plt.scatter(data['rolling_mean'], data['sales'], alpha=0.5)
plt.title('Scatter Plot of Sales vs. Rolling Mean')
plt.xlabel('Rolling Mean')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
# Scatter plot of sales vs. a different numerical variable (e.g., rolling_std)
plt.figure(figsize=(10, 6))
plt.scatter(data['rolling_std'], data['sales'], alpha=0.5)
plt.title('Scatter Plot of Sales vs. Rolling Std Deviation')
plt.xlabel('Rolling Std Deviation')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
#STATISTICAL METHOD:

# %%
import numpy as np

# %%
# Define the threshold for identifying outliers (e.g., 2)
threshold = 2

# Calculate the Z-Score for the log-transformed sales data
from scipy import stats
z_scores = stats.zscore(data['sales'])
outlier_indices = np.where(np.abs(z_scores) > threshold)

# %%
# Calculate the Modified Z-Score for the log-transformed sales data

median_log = np.median(data['sales'])
mad_log = np.median(np.abs(data['sales'] - median_log))
modified_z_scores_log = 0.6745 * (data['sales'] - median_log) / mad_log
outlier_indices_modified_log = np.where(np.abs(modified_z_scores_log) > threshold)

# %%
sns.boxplot(x=data['sales'])
# Out:
# <Axes: xlabel='sales'>

# %%
data['sales'] = np.log1p(data['sales'])

# %%
sns.boxplot(x=data['sales'])
# Out:
# <Axes: xlabel='sales'>

# %% [markdown]
# ##### distribution of the 'sales' data after applying the log transformation.

# %% [markdown]
# # Plot ACF and PACF

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# # Plot ACF
# plot_acf(data['sales'], lags=20) 
# plt.title('Autocorrelation Function (ACF)')
# plt.xlabel('Lag')
# plt.ylabel('ACF Value')
# plt.show()

# %% [markdown]
# ## our dataset is very large, so we sampled our data MONTHLY for plotting.

# %%
# Resample the data to monthly frequency ('M' stands for month-end frequency)
weekly_data = data['sales'].resample('W').mean()

# %%
# Plot ACF
plt.figure(figsize=(12, 4))
plot_acf(weekly_data, lags=36)  # Adjust 'lags' as needed
plt.title('ACF (AutoCorrelation Function) of Monthly Sales Data')
plt.xlabel('Lag')
plt.ylabel('ACF')
plt.show()

# %% [markdown]
# #### Spikes that are above the dashed line (confidence interval) are considered significant.
# #### The lag at which the ACF plot crosses the confidence interval for the first time from above is the order of the Moving Average (MA) term (q)
# #### If there is a gradual decay in the ACF plot after the initial spike, it suggests a non-seasonal MA term. If there's a repeating pattern, it might indicate seasonality.

# %%
# Plot PACF
plt.figure(figsize=(12, 4))
plot_pacf(weekly_data, lags=24)  # Adjust 'lags' as needed
plt.title('PACF (Partial AutoCorrelation Function) of Monthly Sales Data')
plt.xlabel('Lag')
plt.ylabel('PACF')
plt.show()
# Out:
# /Users/deeptilalwani/Downloads/anaconda3/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# #### p (AR Order): Since the PACF plot shows a significant spike at lag 1  we start by considering an ARIMA model with p = 1.
# #### we need to experiment with different values of p (p = 1, p = 2) and see which one provides the best model fit.
#
# #### q (MA Order):  highest significant lag in the ACF plot is lag 1 , lag2,(q = 1, q = 2)

# %% [markdown]
# # Model Building
# ### Time series model

# %% [markdown]
# ### 1. ARIMA Model

# %%
#INITIAL MODEL
#Starting with p = 1 (AR Order) and q = 1 (MA Order) and d = 1

# %% [markdown]
# ##### we have used 2 times differencing to make the data stationary, therefore we take d=2

# %%
from statsmodels.tsa.arima.model import ARIMA

# Fit the initial ARIMA model
initial_model = ARIMA(weekly_data, order=(1, 1, 1))
initial_results = initial_model.fit()

# %%
#model summary
print(initial_results.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  sales   No. Observations:                  242
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                 120.364
# Date:                Wed, 13 Sep 2023   AIC                           -234.728
# Time:                        09:34:43   BIC                           -224.274
# Sample:                    01-06-2013   HQIC                          -230.516
#                          - 08-20-2017
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3270      1.114     -0.294      0.769      -2.510       1.856
# ma.L1          0.2255      1.130      0.200      0.842      -1.989       2.440
# sigma2         0.0216      0.001     26.354      0.000       0.020       0.023
# ...

# %%
#Experiment with Different Orders

# %%
# Try different combinations of p and q
model_1 = ARIMA(weekly_data, order=(1, 1, 1))
results_1 = model_1.fit()

model_2 = ARIMA(weekly_data, order=(1, 1, 2))
results_2 = model_2.fit()

# model_3 = ARIMA(weekly_data, order=(2, 2, 2))
# results_3 = model_3.fit()

# Evaluate the performance of each model
print(results_1.summary())
print(results_2.summary())
# print(results_3.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  sales   No. Observations:                  242
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                 120.364
# Date:                Wed, 13 Sep 2023   AIC                           -234.728
# Time:                        09:34:43   BIC                           -224.274
# Sample:                    01-06-2013   HQIC                          -230.516
#                          - 08-20-2017
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3270      1.114     -0.294      0.769      -2.510       1.856
# ma.L1          0.2255      1.130      0.200      0.842      -1.989       2.440
# sigma2         0.0216      0.001     26.354      0.000       0.020       0.023
# ...

# %% [markdown]
# #### 1.1 Model Selection

# %%
# Compare AIC and BIC values of different models
print("Model 1 AIC:", results_1.aic, "BIC:", results_1.bic)
print("Model 2 AIC:", results_2.aic, "BIC:", results_2.bic)
# print("Model 3 AIC:", results_3.aic, "BIC:", results_3.bic)
# Out:
# Model 1 AIC: -234.72813637287715 BIC: -224.27374557240518
# Model 2 AIC: -232.7869433900495 BIC: -218.84775565608686

# %% [markdown]
# ###### choosing the model with the lowest AIC or BIC value  i.e Model 2 (1,1,2)

# %%
best_model = results_2

# %%
# Residuals of the best model
residuals = best_model.resid

# %%
# Plot the residuals
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(residuals)
plt.title('Residuals of the Best ARIMA Model')
plt.xlabel('Time')
plt.ylabel('Residuals')
plt.show()

# %% [markdown]
# ##### The mean of the residuals is close to zero and there is no significant correlation in the residuals series
# ##### variation of the residuals stays much the same across the data
# ##### The residuals appear as a random scatter around zero without any visible trends or patterns.

# %%
# Summary statistics of residuals
print(residuals.describe())
# Out:
# count    242.000000
# mean       0.015174
# std        0.186805
# min       -0.741229
# 25%       -0.028130
# 50%       -0.002407
# 75%        0.039540
# max        1.808188
# dtype: float64

# %% [markdown]
# ##### Mean: This value is close to zero, which suggests that, on average, our model is not systematically overestimating or underestimating the observed values.
# ##### A lower standard deviation indicates less variability.
# ##### Minimum: The minimum residual value is approximately -0.7412.
# ##### 25th Percentile (Q1): The 25th percentile (lower quartile) of the residuals is approximately -0.076
# ##### Median (50th Percentile, Q2): 0.0028, This is the middle value of the sorted residuals and is close to zero.
# ##### 75th Percentile (Q3): The 75th percentile (upper quartile) of the residuals is approximately 0.039. This value represents the data point below which 75% of the residuals fall.
# ##### Maximum: The maximum residual value is approximately 1.808.

# %%
# Plot ACF and PACF of residuals
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.figure(figsize=(12, 6))
plot_acf(residuals, lags=20)
plt.title('ACF of Residuals')
plt.xlabel('Lags')
plt.ylabel('ACF')
plt.show()

plt.figure(figsize=(12, 6))
plot_pacf(residuals, lags=20)
plt.title('PACF of Residuals')
plt.xlabel('Lags')
plt.ylabel('PACF')
plt.show()
# Out:
# /Users/deeptilalwani/Downloads/anaconda3/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# ###### ACF: (ACF measures the correlation between residuals at different lags) All autocorrelations at lags are close to zero.
# ####### This is a good indication that the residuals do not exhibit autocorrelation and behave like white noise.
#
# ###### PACF : (PACF helps identify the lag at which any autocorrelation exists) All partial autocorrelations are close to zero.
# ####### This supports the idea that there is no remaining autocorrelation in the residuals.
#
# #### it appears that this ARIMA model has successfully captured the underlying patterns in the data, and the residuals exhibit white noise characteristics.
# #### considering this ARIMA model with the selected parameters as our final model for forecasting future values of the time series,
# #### i.e order=(1, 1, 2)

# %% [markdown]
# ### 1.2 evaluate model performance

# %%
from sklearn.metrics import mean_squared_error

# %%
# Split the data into training and testing sets
train_size = int(len(weekly_data) * 0.8)
train, test = weekly_data[:train_size], weekly_data[train_size:]

# %%
# Fit the final ARIMA model on the training data
final_model = ARIMA(train, order=(1, 1, 2))
final_results = final_model.fit()
# Out:
# /Users/deeptilalwani/Downloads/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %%
# Make predictions on the testing data
predictions = final_results.forecast(steps=len(test))

# %%
# Calculate RMSE (Root Mean Squared Error) as a performance metric
rmse = mean_squared_error(test, predictions, squared=False)
print(f"RMSE: {rmse:.2f}")
# Out:
# RMSE: 0.18

# %% [markdown]
# #### Lower RMSE values suggest better model performance, so an RMSE of 0.18 suggests that this ARIMA model is making reasonably accurate predictions.

# %%
# Calculate MAPE (Mean Absolute Percentage Error)
mape_arima = np.mean(np.abs((test - predictions) / test)) * 100
print(f"MAPE_ARIMA: {mape_arima:.2f}%")
# Out:
# MAPE_ARIMA: 4.56%

# %%
accuracy_arima = 100.0 - mape_arima
print(f"Accuracy ARIMA: {accuracy_arima:.2f}%")
# Out:
# Accuracy ARIMA: 95.44%

# %%
weekly_data
# Out:
# date
# 2013-01-06    1.808188
# 2013-01-13    2.078275
# 2013-01-20    2.083418
# 2013-01-27    2.057036
# 2013-02-03    2.091699
#                 ...
# 2017-07-23    3.580738
# 2017-07-30    3.598546
# 2017-08-06    3.673206
# 2017-08-13    3.598425
# 2017-08-20    3.568145
# Freq: W-SUN, Name: sales, Length: 242, dtype: float64

# %% [markdown]
# ### 2. SARIMA MODEL

# %% [markdown]
# # Define SARIMA orders
# #### p = 1  # Autoregressive order
# #### d = 1  # Regular differencing order (already applied)
# #### q = 2  # Moving Average order
# #### s = 52  # Seasonal order for weekly data

# %%
# Calculate the ACF and PACF of the differenced series
differenced_data = weekly_data.diff(periods=1).dropna()

# Plot the ACF and PACF
plt.figure(figsize=(12, 6))
plt.subplot(211)
plot_acf(differenced_data, lags=40, ax=plt.gca())
plt.title('ACF of Differenced Sales')
plt.subplot(212)
plot_pacf(differenced_data, lags=40, ax=plt.gca())
plt.title('PACF of Differenced Sales')
plt.show()
# Out:
# /Users/deeptilalwani/Downloads/anaconda3/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# ##### The PACF plot shows significant spikes at lag 4 and lag 5, highest is at lag=5,set P = 5.
# ##### The ACF plot shows a significant spike at lag 4, set Q = 4

# %%
p = 1  # Autoregressive order
d = 1  # Regular differencing order
q = 2  # Moving Average order
s = 52  # Seasonal order 
# P = 5  # Seasonal Autoregressive order
D = 1  # Seasonal Differencing order
# Q = 4  # Seasonal Moving Average order
# But, SARIMA models with higher orders (P, D, Q, p, d, q) can be computationally intensive.

# %%
#start with
P = 1  # Reduced Seasonal Autoregressive order
Q = 1  # Reduced Seasonal Moving Average order

# %%
# Create and fit the SARIMA model
import statsmodels.api as sm
sarima_model = sm.tsa.SARIMAX(weekly_data, order=(p, d, q), seasonal_order=(P, D, Q, s))
sarima_results = sarima_model.fit()
# Out:
# /Users/deeptilalwani/Downloads/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.83114D-01    |proj g|=  8.26646D-01
#  This problem is unconstrained.
# At iterate    5    f= -3.67635D-01    |proj g|=  1.15955D-01
#
# At iterate   10    f= -3.75775D-01    |proj g|=  6.33468D-02
#
# At iterate   15    f= -3.88239D-01    |proj g|=  1.21255D-01
#
# At iterate   20    f= -3.96776D-01    |proj g|=  1.97427D-01
#
# At iterate   25    f= -4.01686D-01    |proj g|=  1.40336D-01
#
# At iterate   30    f= -4.03616D-01    |proj g|=  6.49050D-03
#
# ...

# %%
# Get the residuals
sarima_residuals = sarima_results.resid

# Plot the residuals
plt.figure(figsize=(12, 6))
plt.plot(sarima_residuals)
plt.title('Residuals of SARIMA Model')
plt.xlabel('Time')
plt.ylabel('Residuals')
plt.show()

# %%
# Plot ACF and PACF of residuals
plt.figure(figsize=(12, 6))
plot_acf(sarima_residuals, lags=20)
plt.title('ACF of Residuals')
plt.xlabel('Lags')
plt.ylabel('ACF')
plt.show()

plt.figure(figsize=(12, 6))
plot_pacf(sarima_residuals, lags=20)
plt.title('PACF of Residuals')
plt.xlabel('Lags')
plt.ylabel('PACF')
plt.show()
# Out:
# /Users/deeptilalwani/Downloads/anaconda3/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# WE TRY WITH INCREASING PARAMETERS (P,D,Q,s)

# %%
# Define SARIMA orders
p = 1  # Autoregressive order
d = 1 # Regular differencing order
q = 2  # Moving Average order
s = 52  # Seasonal order (seasonality of 7)
P = 2  # Seasonal Autoregressive order (increased from 1)
D = 1  # Seasonal Differencing order
Q = 2  # Seasonal Moving Average order (increased from 1)

# %%
# Create and fit the SARIMA model
sarima_model = sm.tsa.SARIMAX(weekly_data, order=(p, d, q), seasonal_order=(P, D, Q, s))
sarima_results = sarima_model.fit()
# Out:
# /Users/deeptilalwani/Downloads/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.21108D-01    |proj g|=  4.02144D-01
#  This problem is unconstrained.
# At iterate    5    f= -3.71938D-01    |proj g|=  6.42219D-02
#
# At iterate   10    f= -3.87580D-01    |proj g|=  7.54407D-02
#
# At iterate   15    f= -3.98435D-01    |proj g|=  1.10512D-01
#
# At iterate   20    f= -4.02398D-01    |proj g|=  5.30794D-02
#
# At iterate   25    f= -4.03580D-01    |proj g|=  8.10536D-02
#
# At iterate   30    f= -4.03658D-01    |proj g|=  7.28143D-04
#
# ...

# %%
# Plot residuals, ACF, and PACF of residuals
residuals = sarima_results.resid
plt.figure(figsize=(12, 6))

# Residuals plot
plt.subplot(3, 1, 1)
plt.plot(residuals)
plt.title('Residuals Plot')
# Out:
# Text(0.5, 1.0, 'Residuals Plot')

# %%
# ACF of residuals
plt.subplot(3, 1, 2)
sm.graphics.tsa.plot_acf(residuals, lags=40, ax=plt.gca())
plt.title('ACF of Residuals')

# PACF of residuals
plt.subplot(3, 1, 3)
sm.graphics.tsa.plot_pacf(residuals, lags=40, ax=plt.gca())
plt.title('PACF of Residuals')

plt.tight_layout()
plt.show()
# Out:
# /Users/deeptilalwani/Downloads/anaconda3/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# ##### getting no significant spike ,outside shaded region,it's a reasonable indication that the current model may be sufficient for capturing the underlying patterns

# %% [markdown]
# ### 2.2 Evaluate model

# %%
# Split the data into training and testing sets
train_size = int(len(weekly_data) * 0.8)
train, test = weekly_data[:train_size], weekly_data[train_size:]

# %%
# Fit the SARIMA model on the training data
sarima_model = sm.tsa.SARIMAX(train, order=(p, d, q), seasonal_order=(P, D, Q, s))
sarima_results = sarima_model.fit()
# Out:
# /Users/deeptilalwani/Downloads/anaconda3/lib/python3.10/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.07110D-01    |proj g|=  3.44481D-01
#  This problem is unconstrained.
# At iterate    5    f= -2.57971D-01    |proj g|=  1.07068D-01
#
# At iterate   10    f= -3.37006D-01    |proj g|=  6.55678D-02
#
# At iterate   15    f= -3.55680D-01    |proj g|=  1.28507D-01
#
# At iterate   20    f= -3.66624D-01    |proj g|=  2.72771D-02
#
# At iterate   25    f= -3.66693D-01    |proj g|=  9.79905D-03
#
# At iterate   30    f= -3.67529D-01    |proj g|=  1.74085D-01
#
# ...

# %%
# Make predictions on the testing data
forecast_steps = len(test)
sarima_forecast = sarima_results.forecast(steps=forecast_steps)

# %%
#Calculate RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(test, sarima_forecast))
print(f"RMSE: {rmse:.2f}")
# Out:
# RMSE: 0.32

# %%
# Calculate MAPE (Mean Absolute Percentage Error)
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape_sarima = mean_absolute_percentage_error(test, sarima_forecast)
print(f"MAPE_SARIMA: {mape_sarima:.2f}%")
# Out:
# MAPE_SARIMA: 6.42%

# %%
accuracy_sarima= 100.0 - mape_sarima
print(f"Accuracy SARIMA: {accuracy_sarima:.2f}%")
# Out:
# Accuracy SARIMA: 93.58%

# %% [markdown]
# ### 3.SIMPLE MOVING AVERAGE MODEL

# %%
# Calculate SMA with window of 7 days
sma_7 = weekly_data.rolling(window=7).mean()

# Calculate SMA with window of 30 days 
sma_30 = weekly_data.rolling(window=30).mean()

# Plot the SMAs
plt.figure(figsize=(16,8))
weekly_data.plot(label='Original')
sma_7.plot(label='SMA 7')
sma_30.plot(label='SMA 30')

# Add labels and legend
plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()

plt.show()

# %% [markdown]
# ##### It shows the original sales data along with the three SMAs,o see how each SMA reacts to short-term and long-term trends.
# ##### original sales data , as we can see,fluctuates up and down over time
# ##### sma_7(in orange), follows general rend of original data,but smoothes ot day to day fluctuations
# ##### sma_30(in green), smoother than 7 day pattern,so it reacts more slowly to changes in data

# %%
plt.figure(figsize=(16,8))
sma_30.plot(label='SMA 30')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %% [markdown]
# #####  It focuses specifically on the SMA 30, providing a closer look at how it smoothens the data over a 30-day window.

# %%
#COMPARING PERFORMANCES OF SMA model using different window sizes (7, 30, and 365)
#USING RMSE AND MAPE VALUES

# %%
# Remove missing values (NaN) from SMA calculations
sma_7 = sma_7[7:]
sma_30 = sma_30[30:]

# %%
# Calculate residuals for each window size
residuals_7 = weekly_data[7:] - sma_7
residuals_30 = weekly_data[30:] - sma_30

# %%
# Calculate RMSE for each window size
rmse_7 = np.sqrt(mean_squared_error(weekly_data[7:], sma_7))
rmse_30 = np.sqrt(mean_squared_error(weekly_data[30:], sma_30))

# %%
# Calculate MAPE for each window size
mape_7 = (np.abs(residuals_7) / np.maximum(weekly_data[7:], 1e-6)).mean() * 100
mape_30 = (np.abs(residuals_30) / np.maximum(weekly_data[30:], 1e-6)).mean() * 100

# %%
print(f"SMA 7 - RMSE: {rmse_7:.2f}, MAPE_sma7: {mape_7:.2f}%")
print(f"SMA 30 - RMSE: {rmse_30:.2f}, MAPE_sma30: {mape_30:.2f}%")
# Out:
# SMA 7 - RMSE: 0.17, MAPE_sma7: 3.64%
# SMA 30 - RMSE: 0.27, MAPE_sma30: 6.72%

# %%
accuracy_SMA7 = 100.0 - mape_7
accuracy_SMA30 = 100.0 - mape_30
print(f"Accuracy SMA7: {accuracy_SMA7:.2f}%")
print(f"Accuracy SMA30: {accuracy_SMA30:.2f}%")
# Out:
# Accuracy SMA7: 96.36%
# Accuracy SMA30: 93.28%

# %% [markdown]
# ### 4. Exponential Smoothing (ETS)
# ##### models like Holt-Winters for capturing trend and seasonality

# %%
import statsmodels.api as sm

# %%
# Perform exponential smoothing with Holt-Winters (additive)
model = sm.tsa.ExponentialSmoothing(weekly_data, seasonal='add', seasonal_periods=52)
fit = model.fit()

# %%
# Plot the original data and the fitted values
plt.figure(figsize=(12, 6))
plt.plot(weekly_data.index, weekly_data, label='Original Data', color='blue')
plt.plot(weekly_data.index, fit.fittedvalues, label='Fitted Values (Holt-Winters)', color='red')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()
plt.title('Weekly Data with Holt-Winters Exponential Smoothing')
plt.show()

# %% [markdown]
# ##### The blue line represents original weekly sales data.
# ##### we observe the  seasonality, and any irregularities or fluctuations in the data.
#
# ##### The red line represents the fitted values generated by the Holt-Winters Exponential Smoothing model.
# ##### These fitted values are the model's estimates of our sales data based on the observed trend and seasonality patterns.
# ##### The model attempts to capture both the trend (long-term movement) and seasonality (repeating patterns) in our data.
#
# ### Where the red line closely follows the blue line, it indicates that the model is doing a good job of capturing the observed patterns in the data.
# ### Differences between the blue and red lines can highlight discrepancies where the model may not fully capture irregularities or fluctuations.
#
# #### overall,we can see how well the Holt-Winters Exponential Smoothing model fits our weekly sales data

# %% [markdown]
# ### 4.2 evaluation

# %%
# Calculate Residuals
residuals = weekly_data - fit.fittedvalues

# %%
# Calculate RMSE
rmse = np.sqrt((residuals ** 2).mean())

# %%
# Calculate MAPE
mape = (np.abs(residuals) / weekly_data).mean() * 100

# %%
# Print RMSE and MAPE
print("RMSE:", rmse)
print("MAPE:", mape)
# Out:
# RMSE: 0.10817396133240767
# MAPE: 2.1484697339196144

# %%
y_true = weekly_data 
y_pred = fit.fittedvalues

# %%
# Calculate MAPE as a percentage
mape_exp = (np.abs((y_true - y_pred) / y_true)).mean() * 100

print(f"MAPE_exp: {mape_exp:.2f}%")
# Out:
# MAPE_exp: 2.15%

# %%
accuracy_exp= 100.0 - mape_exp
print(f"Accuracy EXP: {accuracy_exp:.2f}%")
# Out:
# Accuracy EXP: 97.85%

# %% [markdown]
# ### Triple Exponential Smoothing (Holt-Winters with Seasonality)
# ### 4.3 Parameter Interpretation:
#
# #### It has three smoothing parameters: alpha (α), beta (β), and gamma (γ). These parameters control the model's behavior and how it responds to different components of a time series, including level, trend, and seasonality.
# #### Alpha (α) is primarily concerned with capturing the level or baseline of the time series.
# #### Beta (β) focuses on modeling and capturing the trend in the data.
# #### Gamma (γ) deals with seasonality, capturing repeating patterns in the data.

# %%
# Extract the smoothing parameters
alpha = fit.params['smoothing_level']  # Alpha (level smoothing)
beta = fit.params['smoothing_trend']   # Beta (trend smoothing)
gamma = fit.params['smoothing_seasonal']  # Gamma (seasonality smoothing)

# %%
# Interpretation of the parameters
print(f"Alpha (Level Smoothing): {alpha:.4f}")
print(f"Beta (Trend Smoothing): {beta}")
print(f"Gamma (Seasonality Smoothing): {gamma:.4f}")
# Out:
# Alpha (Level Smoothing): 1.0000
# Beta (Trend Smoothing): nan
# Gamma (Seasonality Smoothing): 0.0000

# %% [markdown]
# #### we can see, it is not giving proper results
# #### we need to iteratively adjust your modeling approach, including the choice of initial parameter values and model specifications, until we achieve a satisfactory fit to our time series data.

# %%
# Choose initial values for alpha, beta, and gamma
initial_alpha_values = [0.1, 0.3, 0.5]
initial_beta_values = [0.1, 0.2]
initial_gamma_values = [0.1, 0.2]

# %% [markdown]
# ##### GRID SEARCH to systematically explore combinations of alpha,beta and gamma :

# %%
import itertools

# Create a grid of parameter combinations
parameter_grid = list(itertools.product(initial_alpha_values, initial_beta_values, initial_gamma_values))

# %%
# Initialize variables to track the best parameters and corresponding MAE
best_parameters = None
best_mae = float('inf')

# %%
# Split the data into training and validation sets

split_point = int(len(weekly_data) * 0.8)  # 80% training, 20% validation
training_data = weekly_data[:split_point]
validation_data = weekly_data[split_point:]

# %%
# Iterate through the parameter grid
for alpha, beta, gamma in parameter_grid:
    # Fit the Exponential Smoothing model on the training data
    model = sm.tsa.ExponentialSmoothing(training_data, trend='add', seasonal='add', seasonal_periods=52)
    fit = model.fit(smoothing_level=alpha, smoothing_trend=beta, smoothing_seasonal=gamma)
    
    # Generate forecasts for the validation period
    forecast_periods = len(validation_data)  # Forecast the entire validation period
    forecast_values = fit.forecast(steps=forecast_periods)
    
    # Calculate MAE for the forecasts using the validation data
    mae = np.mean(np.abs(forecast_values - validation_data))
    
    # Check if this set of parameters results in a lower MAE
    if mae < best_mae:
        best_mae = mae
    best_parameters = (alpha, beta, gamma)

# %%
# Print the best parameters and corresponding MAE
print(f"Best Parameters (alpha, beta, gamma): {best_parameters}")
print(f"Best MAE: {best_mae}")
# Out:
# Best Parameters (alpha, beta, gamma): (0.5, 0.2, 0.2)
# Best MAE: 0.44626398366791237

# %% [markdown]
# #### Alpha (Level Smoothing): 0.5
# #### Beta (Trend Smoothing): 0.2
# #### Gamma (Seasonality Smoothing): 0.2
#
# #### MAE: .4463, which indicates the accuracy of our Exponential Smoothing model's forecasts on the validation dataset.

# %% [markdown]
# ### 4.4 final Exponential Smoothing model using these optimized parameters

# %%
# Create the Exponential Smoothing model with optimized parameters
final_model = sm.tsa.ExponentialSmoothing(weekly_data, trend='add', seasonal='add', seasonal_periods=52)
fit = final_model.fit(smoothing_level=0.5, smoothing_trend=0.2, smoothing_seasonal=0.2)

# %%
# Fit the model to the entire dataset
fit = final_model.fit()

# %%
forecast_periods = len(validation_data) # Number of periods to forecast
forecast_values = fit.forecast(steps=forecast_periods)

# %%
#EVALUATING FINAL MODEL

# %%
len(forecast_values)
# Out:
# 49

# %%
len(validation_data)
# Out:
# 49

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Calculate MAE and MSE
mae = mean_absolute_error(validation_data, forecast_values)
mse = mean_squared_error(validation_data, forecast_values)

# Print the evaluation metrics
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Absolute Error (MAE): 0.32
# Mean Squared Error (MSE): 0.12

# %%
from sklearn.metrics import mean_absolute_percentage_error

# Calculate MAPE using mean_absolute_percentage_error
mape_TRIPLEexp = mean_absolute_percentage_error(validation_data, forecast_values)

# Print MAPE
print(f"Mean Absolute Percentage Error (MAPE)_TRIPLEexp: {mape_TRIPLEexp:.2f}%")
# Out:
# Mean Absolute Percentage Error (MAPE)_TRIPLEexp: 0.09%

# %%
accuracy_TRIPLEexp= 100.0 - mape_TRIPLEexp
print(f"Accuracy TRIPLEexp: {accuracy_TRIPLEexp:.2f}%")
# Out:
# Accuracy TRIPLEexp: 99.91%

# %% [markdown]
# #### A low MAPE value like this suggests that the model's predictions closely align with the observed sales data for the validation period, which is a positive outcome for our forecasting efforts.

# %% [markdown]
# ### 5. RANDOM FOREST

# %%
weekly_data
# Out:
# date
# 2013-01-06    1.808188
# 2013-01-13    2.078275
# 2013-01-20    2.083418
# 2013-01-27    2.057036
# 2013-02-03    2.091699
#                 ...
# 2017-07-23    3.580738
# 2017-07-30    3.598546
# 2017-08-06    3.673206
# 2017-08-13    3.598425
# 2017-08-20    3.568145
# Freq: W-SUN, Name: sales, Length: 242, dtype: float64

# %% [markdown]
# #### the time series itself serves as both the feature and the target variable.
# ##### So,we can use the time series directly as both X and y.
# #### we have already aggregated our weekly_data

# %%
# Define target variable (weekly sales)
y = weekly_data

# %% [markdown]
# ##### we know,there is a potential relationship or pattern in the data based on the date or time.
# ##### so i used the date index as a feature for our Random Forest model

# %%
# Reshape the index to a 2D array
X = y.index.values.reshape(-1, 1)

# %% [markdown]
# ##### X array contains the date information from the index of our time series data and is structured as a 2D array with one column.
# ##### By using the datetime index as a feature, we allow the Random Forest model to capture any patterns or trends in the sales data that change over time.

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
# Adjust the test_size as needed, depending on how much data you want to reserve for testing
X_train, X_test, y_train, y_test = train_test_split(X, y.values, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

# Create and train the Random Forest model
rf_model = RandomForestRegressor(n_estimators=100, random_state=0)
rf_model.fit(X_train, y_train)

# Make predictions
y_pred_rf = rf_model.predict(X_test)

# %%
# Create a plot
plt.figure(figsize=(12, 6))
plt.plot( y_test, label="Actual Data", color="blue")
plt.plot( y_pred_rf, label="Random Forest Predictions", color="red")

# Add labels and a legend
plt.xlabel("Time")
plt.ylabel("Sales")
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# #### we can see the predictions still almost capturing the trend

# %%
# Evaluate the model's performance
mae = mean_absolute_error(y_test, y_pred_rf)
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# Mean Absolute Error: 0.06

# %%
# Calculate MAPE
mape_RF = np.mean(np.abs((y_test - y_pred_rf) / y_test)) * 100

print(f"MAPE as a Percentage_RF: {mape_RF:.2f}%")
# Out:
# MAPE as a Percentage_RF: 1.94%

# %%
accuracy_RF= 100.0 - mape_RF
print(f"Accuracy RF: {accuracy_RF:.2f}%")
# Out:
# Accuracy RF: 98.06%

# %% [markdown]
# ### 6.DECISION TREES

# %%
from sklearn.tree import DecisionTreeRegressor

# Create and train the Decision Tree model
decision_tree_model = DecisionTreeRegressor(random_state=0)
decision_tree_model.fit(X_train, y_train)

# Make predictions
y_pred_dt = decision_tree_model.predict(X_test)

# %%
# Calculate RMSE and MAE
rmse = np.sqrt(mean_squared_error(y_test, y_pred_dt))
mae = mean_absolute_error(y_test, y_pred_dt)

print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Root Mean Squared Error (RMSE): 0.10
# Mean Absolute Error (MAE): 0.06

# %%
# Calculate MAPE
mape_DT = np.mean(np.abs((y_test - y_pred_dt) / y_test)) * 100

print(f"MAPE as a Percentage DT: {mape_DT:.2f}%")
# Out:
# MAPE as a Percentage DT: 2.02%

# %%
accuracy_DT= 100.0 - mape_DT
print(f"Accuracy DT: {accuracy_DT:.2f}%")
# Out:
# Accuracy DT: 97.98%

# %% [markdown]
# ### 7.LINEAR REGRESSION

# %%
y = weekly_data.values.reshape(-1, 1)  # Reshape into a 2D array
X = np.arange(1, len(y) + 1).reshape(-1, 1)  # feature representing the dateindex

# %% [markdown]
# ##### X uses np.arange(1, len(y) + 1) to generate a sequence of numbers from 1 to the length of y, which represents date points.
# ##### using the date index as a feature, we are allowing the model to capture any linear trend or pattern in the sales data that changes over time.

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#Create and train the Linear Regression model
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

# Make predictions
y_pred_lr = lr_model.predict(X_test)

# %%
# Create a plot
plt.figure(figsize=(12, 6))
plt.plot(y_test, label="Actual Data", color="blue")
plt.plot(y_pred_lr, label="Linear Regression Predictions", color="green")

# Add labels and a legend
plt.xlabel("Time")
plt.ylabel("Sales")
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# #### The Linear Regression model produces a trend line that tries to fit the overall upward or downward movement in the data. It doesn't capture the more complex patterns or fluctuations.

# %%
# Calculate RMSE and MAE
rmse = np.sqrt(mean_squared_error(y_test, y_pred_lr))
mae = mean_absolute_error(y_test, y_pred_lr)

print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Root Mean Squared Error (RMSE): 0.25
# Mean Absolute Error (MAE): 0.21

# %%
# Calculate MAPE
mape_LR = np.mean(np.abs((y_test - y_pred_lr) / y_test)) * 100

print(f"MAPE as a Percentage LR: {mape_LR:.2f}%")
# Out:
# MAPE as a Percentage LR: 7.53%

# %%
accuracy_LR= 100.0 - mape_LR
print(f"Accuracy LR: {accuracy_LR:.2f}%")
# Out:
# Accuracy LR: 92.47%

# %% [markdown]
# ### 8.Neural Network Model
#
# ##### scikit-learn's RandomizedSearchCV method to perform hyperparameter tuning for our MLPRegressor model.
# ##### using MLPRegressor for our neural network model

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import RandomizedSearchCV

# %%
y = weekly_data.values.reshape(-1, 1)
X = np.arange(1, len(y) + 1).reshape(-1, 1)  # Create a feature representing the time index

# %%
# Create an instance of MLPRegressor
mlp_model = MLPRegressor()

# %%
# Define hyperparameter grid for RandomizedSearch
param_grid = {
    'hidden_layer_sizes': [(50,), (100,), (50, 50), (100, 50)],
    'activation': ['relu', 'tanh'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

# Create RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=mlp_model, param_distributions=param_grid, 
                                   n_iter=10, scoring='neg_mean_squared_error', cv=5, random_state=0)

# %% [markdown]
# ##### The search is performed with 10 iterations (n_iter=10) and 5-fold cross-validation (cv=5) to find the best hyperparameters.

# %%
# Fit the RandomizedSearchCV on your data
random_search.fit(X, y)

# Get the best model with the optimized hyperparameters
best_mlp_model = random_search.best_estimator_
# Out:
# /Users/deeptilalwani/Downloads/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/deeptilalwani/Downloads/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/deeptilalwani/Downloads/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
# Print the best hyperparameters
print("Best Hyperparameters:")
print(random_search.best_params_)
# Out:
# Best Hyperparameters:
# {'learning_rate': 'adaptive', 'hidden_layer_sizes': (100, 50), 'alpha': 0.01, 'activation': 'tanh'}

# %% [markdown]
# ##### Learning Rate: 'constant': This hyperparameter controls the step size at each iteration while moving toward a minimum of the loss function. A 'constant' learning rate means the learning rate remains the same throughout training.
#
# ##### Hidden Layer Sizes: (100,): The MLPRegressor has a single hidden layer with 100 neurons. This architecture complexity can capture relatively complex relationships in the data.
#
# ##### Alpha (L2 Regularization): 0.001 :mild regularization effect, helps prevent overfitting by adding a penalty term to the loss function.
#
# ##### Activation Function: 'tanh' : The 'tanh' activation function is the hyperbolic tangent function, It can model complex, nonlinear relationships in the data.
#
# ### This gives balance model complexity (via hidden layer size) and regularization (via alpha) while using a standard learning rate and a versatile activation function.
# ### These hyperparameters were chosen based on their performance in minimizing the Mean Squared Error (MSE) during the training process.

# %% [markdown]
# ### 8.2 model evaluation

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Make predictions on the testing data
y_pred = best_mlp_model.predict(X_test)

# %%
# Calculate RMSE and MAE for evaluation
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)

# Print the evaluation metrics
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Root Mean Squared Error (RMSE): 0.25
# Mean Absolute Error (MAE): 0.20

# %%
from sklearn.metrics import mean_absolute_error

# Calculate MAE (Mean Absolute Error)
mae = mean_absolute_error(y_test, y_pred)

# %%
# Calculate MAPE (Mean Absolute Percentage Error)
mape = (mae / y_test.mean()) * 100

print(f"MAPE: {mape:.2f}%")
# Out:
# MAPE: 6.96%

# %%
accuracy_NN = 100.0 - mape
print(f"Accuracy NN: {accuracy_NN:.2f}%")
# Out:
# Accuracy NN: 93.04%

# %% [markdown]
# # Comparison and selecting the best model

# %%
mape_values = {
    "ARIMA": 4.56,
    "SARIMA": 6.42,
    "SMA": 3.64,
    "Exponential Smoothing": 2.15,
    "Triple Exponential Smoothing ": 0.09,
    "Random Forest": 1.94,
    "Decision Trees": 2.02,
    "Linear Regression": 7.53,
    "Neural Network": 7.29
}

# %%
# Find the model with the lowest MAPE
best_model = min(mape_values, key=mape_values.get)
best_mape = mape_values[best_model]

# %%
print(f"The best-performing model is '{best_model}' with a MAPE of {best_mape:.2f}%")
# Out:
# The best-performing model is 'Triple Exponential Smoothing ' with a MAPE of 0.09%

# %% [markdown]
# # Average Demand Interval (ADI) and the square of the Coefficient of Variation (CV²)
# ##### to assess the forecastability of your models.

# %%
# Calculate ADI (Average Demand Interval)
adi_values = {model: 100 / mape for model, mape in mape_values.items()}

# Print ADI values
for model, adi in adi_values.items():
    print(f"{model}: ADI = {adi:.2f}")
# Out:
# ARIMA: ADI = 21.93
# SARIMA: ADI = 15.58
# SMA: ADI = 27.47
# Exponential Smoothing: ADI = 46.51
# Triple Exponential Smoothing : ADI = 1111.11
# Random Forest: ADI = 51.55
# Decision Trees: ADI = 49.50
# Linear Regression: ADI = 13.28
# Neural Network: ADI = 13.72

# %%
# Calculate CV² (Square of Coefficient of Variation)
cv2_values = {model: mape ** 2 for model, mape in mape_values.items()}

# Print CV² values
for model, cv2 in cv2_values.items():
    print(f"{model}: CV² = {cv2:.2f}")
# Out:
# ARIMA: CV² = 20.79
# SARIMA: CV² = 41.22
# SMA: CV² = 13.25
# Exponential Smoothing: CV² = 4.62
# Triple Exponential Smoothing : CV² = 0.01
# Random Forest: CV² = 3.76
# Decision Trees: CV² = 4.08
# Linear Regression: CV² = 56.70
# Neural Network: CV² = 53.14

# %%
# Define the MAPE, ADI, and CV² values for each model
forecasting_metrics = {
    "ARIMA": {"MAPE": 4.56, "ADI": 21.93, "CV²": 20.79},
    "SARIMA": {"MAPE": 6.42, "ADI": 15.58, "CV²": 41.22},
    "SMA": {"MAPE": 3.64, "ADI": 27.47, "CV²": 13.25},
    "Exponential Smoothing": {"MAPE": 2.15, "ADI": 46.51, "CV²": 4.62},
    "Triple Exponential Smoothing": {"MAPE": 0.09, "ADI": 1111.11, "CV²": 0.01},
    "Random Forest": {"MAPE": 1.94, "ADI": 51.55, "CV²": 3.76},
    "Decision Trees": {"MAPE": 2.02, "ADI": 49.50, "CV²": 4.08},
    "Linear Regression": {"MAPE": 7.53, "ADI": 13.28, "CV²": 56.70},
    "Neural Network": {"MAPE": 7.29, "ADI": 13.72, "CV²": 53.14}
}

# %%
# Find the model with the lowest MAPE
best_mape_model = min(forecasting_metrics, key=lambda x: forecasting_metrics[x]["MAPE"])

# Find the model with the lowest ADI
best_adi_model = min(forecasting_metrics, key=lambda x: forecasting_metrics[x]["ADI"])

# Find the model with the lowest CV²
best_cv2_model = min(forecasting_metrics, key=lambda x: forecasting_metrics[x]["CV²"])

# %%
print(f"Best MAPE Model: {best_mape_model}")
print(f"Best ADI Model: {best_adi_model}")
print(f"Best CV² Model: {best_cv2_model}")
# Out:
# Best MAPE Model: Triple Exponential Smoothing
# Best ADI Model: Linear Regression
# Best CV² Model: Triple Exponential Smoothing

# %% [markdown]
# ### Triple Exponential Smoothing has the lowest MAPE, indicating the best performance in terms of forecast accuracy.
#
# ### Linear Regression has the lowest ADI, suggesting the most regular demand intervals.(capture regulare demand patterns)
# ##### but, Linear Regression has high CV² value, indicating it has more demand variation.,This suggests that while Linear Regression captures regularity, it might not perform well when there are significant variations in demand.
#
# ### Triple Exponential Smoothing also has the lowest CV², indicating the least variation in quantities.(it's very effective in stabilizing demand.)

# %% [markdown]
# ##### If accuracy is paramount, Triple Exponential Smoothing is the top choice. If regularity in demand intervals is critical, Linear Regression is favored. If minimizing variation in quantities is crucial, Triple Exponential Smoothing is again the top pick.

# %% [markdown]
# ### BEST MODEL considers both accuracy and includes regularity and variation.
# ### So, we choose Triple Exponential Smoothing (TES) is the best model for forecast accuracy and demand stability.

# %% [markdown]
# # Model Deployment

# %%
import pickle

with open('final_model.pkl', 'wb') as f:
    pickle.dump(final_model, f)

# %%
with open('final_model.pkl', 'rb') as f:
    loaded_model=pickle.load(f)

# %%
forecast_periods = 100  # We can Adjust this as needed

# Using the predict method to make forecasts
forecast_values = fit.predict(start=len(validation_data), end=len(validation_data) + forecast_periods - 1)
forecast_values
forecast_values.plot()
plt.grid()
